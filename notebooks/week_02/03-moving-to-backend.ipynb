# %% [markdown]
# ### Moving what we implemented from lesson 02 to the backend api code

# %% [markdown]
# install deps

# %% [markdown]
# `uv add --package api instructor`

# %% [markdown]
# now we can update /retrieval_generation.py

# %% [markdown]
#  we will implement the changes in the generate answer function
